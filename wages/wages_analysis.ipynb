# %%
import pandas as pd

r4_df=pd.read_excel('rtisadec2023.xlsx',
sheet_name="20. Median pay (LA)",
header=7,
index_col=0)
r3_df=pd.read_excel('rtisadec2023.xlsx',
                 sheet_name="16. Median pay (NUTS3)",
                 header=6,
                 index_col=0)
r2_df=pd.read_excel('rtisadec2023.xlsx',
                 sheet_name="12. Median pay (NUTS2)",
                 header=6,
                 index_col=0)
r1_df=pd.read_excel('rtisadec2023.xlsx',
                 sheet_name="8. Median pay (NUTS1)",
                 header=6,
                 index_col=0)
                 

datazones=pd.read_excel('../gdp/regionalgrossdomesticproductgdpallitlregions.xlsx',sheet_name='Table 11',header=1,usecols=[0,2])
# Out:
# /home/manuel/platzi/portfolio/current_projects/aberdeen/abervenv/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /home/manuel/platzi/portfolio/current_projects/aberdeen/abervenv/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /home/manuel/platzi/portfolio/current_projects/aberdeen/abervenv/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
all_except_london=[col for col in r1_df.columns[:-1] if col!='London']
r1_df[all_except_london].plot(rot=90)
# Out:
# <Axes: xlabel='Date'>

# %%
r_scotland=['North Eastern Scotland', 'Highlands and Islands',
       'Eastern Scotland', 'West Central Scotland', 'Southern Scotland']
r2_df[r_scotland].plot(rot=90)
# Out:
# <Axes: xlabel='Date'>

# %%
select_east_scotland=['City of Edinburgh','Aberdeen City',
 'Aberdeenshire','Perth and Kinross','Dundee City','Glasgow City']
r4_df[select_east_scotland].plot(figsize=(7,5),rot=90)
# Out:
# <Axes: xlabel='Date'>
